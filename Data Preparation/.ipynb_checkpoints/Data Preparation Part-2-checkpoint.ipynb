# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ASUS\Desktop\New folder (4)\EY_Techathon\CLUSTERING_V5.csv")
# Out:
# C:\Users\ASUS\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=df.drop(['Prediction'],axis=1)

# %%
df.head(2)
# Out:
#   Date Announced    Month  Age Bracket Gender Detected District State code  \
# 0      30-Jan-20  January           20      F          Thrissur         KL
# 1      02-Mar-20    March           45      M        East Delhi         DL
#
#   Detected State   Class Zone  Population Density Type of transmission  \
# 0         Kerala  Orange Zone                 415             Imported
# 1          Delhi  Orange Zone               14675             Imported
#
#   Nationality                          Notes Backup Notes Climate  \
# 0       India           Travelled from Wuhan          NaN    MILD
# 1       India  Travelled from Austria, Italy          NaN    MILD
#
#    Number of Testing Centre Current Status
# 0                        96      Recovered
# 1                        73      Recovered

# %%
df.shape
# Out:
# (102788, 16)

# %%
df1=df[['Detected District','Detected State']]

# %%
df1.isnull().sum()
# Out:
# Detected District    0
# Detected State       0
# dtype: int64

# %%
df['Climate'].value_counts()
# Out:
# RAIN    69404
# HOT     30354
# MILD     2603
# COLD      424
# SNOW        3
# Name: Climate, dtype: int64

# %%
for i in df['Age Bracket']:
    if i>=60:
        df['Age Bracket']=df['Age Bracket'].replace(i,'Senior Citizen')
    if i<=60 and i>25:
        df['Age Bracket']=df['Age Bracket'].replace(i,'Young')
    else:
        df['Age Bracket']=df['Age Bracket'].replace(i,'Children')

# %%
df.head(5)
# Out:
#   Date Announced    Month     Age Bracket Gender Detected District State code  \
# 0      30-Jan-20  January        Children      F          Thrissur         KL
# 1      02-Mar-20    March           Young      M        East Delhi         DL
# 2      02-Mar-20    March        Children      M         Hyderabad         TG
# 3      03-Mar-20    March  Senior Citizen      M            Jaipur         RJ
# 4      04-Mar-20    March  Senior Citizen      F            Jaipur         RJ
#
#   Detected State   Class Zone  Population Density Type of transmission  \
# 0         Kerala  Orange Zone                 415             Imported
# 1          Delhi  Orange Zone               14675             Imported
# 2      Telangana     Red Zone                 200             Imported
# 3      Rajasthan  Orange Zone                 186             Imported
# 4      Rajasthan  Orange Zone                 186             Imported
#
#   Nationality                                              Notes Backup Notes  \
# 0       India                               Travelled from Wuhan          NaN
# 1       India                      Travelled from Austria, Italy          NaN
# 2       India  Travelled from Dubai to Bangalore on 20th Feb,...          NaN
# 3       Italy                               Travelled from Italy          NaN
# 4       Italy                   Travelled from Italy, Wife of P6          NaN
#
#   Climate  Number of Testing Centre Current Status
# 0    MILD                        96      Recovered
# 1    MILD                        73      Recovered
# 2     HOT                        69      Recovered
# 3     HOT                        45      Recovered
# 4     HOT                        45      Recovered

# %%
df['Detected District'].value_counts()
# Out:
# Bengaluru Urban     33352
# Chennai             12987
# Dakshina Kannada     3817
# Chandigarh           3006
# Ballari              2626
#                     ...
# Noney                   1
# West Garo Hills         1
# Panchkula               1
# Andaman                 1
# Charaideo               1
# Name: Detected District, Length: 351, dtype: int64

# %%
df['Age Bracket'].value_counts()
# Out:
# Young             63609
# Children          22265
# Senior Citizen    16914
# Name: Age Bracket, dtype: int64

# %%
df3=df[(df['Detected District']=='Chandigarh')]

# %%
df3['Class Zone'][df3.index[-1]]
# Out:
# 'Red Zone'

# %%
df3['Age Bracket'].value_counts().index[0]
# Out:
# 'Young'

# %%
df_d=pd.read_csv(r"C:\Users\ASUS\Downloads\districts.csv")
df_d.shape
df_d_s=pd.read_csv(r"C:\Users\ASUS\Downloads\case_time_series.csv")

# %%
df_d3=df_d[(df_d['Date']== "2021-01-02" )]

# %%
df_d3
# Out:
#               Date                        State           District  Confirmed  \
# 159037  2021-01-02  Andaman and Nicobar Islands            Unknown       4946
# 159038  2021-01-02               Andhra Pradesh          Anantapur      67374
# 159039  2021-01-02               Andhra Pradesh           Chittoor      86248
# 159040  2021-01-02               Andhra Pradesh      East Godavari     123755
# 159041  2021-01-02               Andhra Pradesh   Foreign Evacuees        434
# ...            ...                          ...                ...        ...
# 159687  2021-01-02                  West Bengal    Purba Bardhaman      12305
# 159688  2021-01-02                  West Bengal    Purba Medinipur      20162
# 159689  2021-01-02                  West Bengal            Purulia       6972
# 159690  2021-01-02                  West Bengal  South 24 Parganas      36117
# 159691  2021-01-02                  West Bengal     Uttar Dinajpur       6470
#
#         Recovered  Deceased  Other    Tested
# 159037       4830        62      0  181640.0
# 159038      66641       597      0  809025.0
# 159039      85087       842      0  791735.0
# 159040     122747       636      0  967422.0
# 159041        434         0      0       NaN
# ...           ...       ...    ...       ...
# 159687      12012        95      0       NaN
# 159688      19410       273      0       NaN
# 159689       6612        47      0       NaN
# 159690      35270       682      0       NaN
# 159691       6233        72      0       NaN
#
# [655 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Date Announced', 'Month', 'Age Bracket', 'Gender', 'Detected District',
#        'State code', 'Detected State', 'Class Zone', 'Population Density',
#        'Type of transmission', 'Nationality', 'Notes', 'Backup Notes',
#        'Climate', 'Number of Testing Centre', 'Current Status'],
#       dtype='object')

# %%
a=[]
for i in df['Detected District'].value_counts().index:
    a.append(i)
a
# Out:
# ['Bengaluru Urban',
#  'Chennai',
#  'Dakshina Kannada',
#  'Chandigarh',
#  'Ballari',
#  'Kalaburagi',
#  'Dharwad',
#  'Mysuru',
#  'Udupi',
#  'Vijayapura',
#  'Yadgir',
#  'Bidar',
#  'Belagavi',
#  'Uttara Kannada',
#  'Davanagere',
#  'Hassan',
#  'Chengalpattu',
#  'Chikkaballapura',
#  'Shivamogga',
#  'Thiruvallur',
#  'Bengaluru Rural',
#  'Mandya',
#  'Tumakuru',
#  'Bagalkote',
#  'Raichur',
#  'Koppal',
#  'Kolar',
#  'Ariyalur',
#  'Gadag',
#  'Haveri',
#  'Dehradun',
#  'Patna',
#  'Cuddalore',
#  'Ramanagara',
#  'Chikkamagaluru',
#  'Ganjam',
#  'Chamarajanagara',
#  'Kancheepuram',
#  'Viluppuram',
#  'Munger',
#  'Rohtas',
#  'Madhubani',
#  'Thiruvananthapuram',
#  'Khordha',
#  'Siwan',
#  'Ahmedabad',
#  'Bhagalpur',
#  'Madurai',
#  'Kodagu',
#  'Chitradurga',
#  'Tirunelveli',
#  'Begusarai',
#  'Gopalganj',
#  'Buxar',
#  'Muzaffarpur',
#  'Nalanda',
#  'Tiruvannamalai',
#  'Katihar',
#  'Purnia',
#  'Nawada',
#  'Nainital',
#  'Samastipur',
#  'Kannur',
#  'Khagaria',
#  'Ernakulam',
#  'Aurangabad',
#  'Kallakurichi',
#  'Supaul',
#  'West Champaran',
#  'Jehanabad',
#  'Kaimur',
#  'Sundargarh',
#  'Malappuram',
#  'Thrissur',
#  'Bhojpur',
#  'Darbhanga',
#  'Perambalur',
#  'Kozhikode',
#  'Banka',
#  'Saran',
#  'Thoothukkudi',
#  'Jajpur',
#  'Alappuzha',
#  'Balasore',
#  'Cuttack',
#  'Vaishali',
#  'Kollam',
#  'Gaya',
#  'Madhepura',
#  'Imphal West',
#  'Saharsa',
#  'Guntur',
#  'Virudhunagar',
#  'East Champaran',
#  'Sitamarhi',
#  'South Goa',
#  'Kishanganj',
#  'Kurnool',
#  'Theni',
#  'Kasaragod',
#  'Mayurbhanj',
#  'Kottayam',
#  'Puri',
#  'Airport Quarantine',
#  'Sheikhpura',
#  'Dindigul',
#  'Sheohar',
#  'Arwal',
#  'Palakkad',
#  'Bhadrak',
#  'Ramanathapuram',
#  'Ranipet',
#  'Imphal East',
#  'Tenkasi',
#  'Coimbatore',
#  'Lakhisarai',
#  'Araria',
#  'Namakkal',
#  'Udham Singh Nagar',
#  'Sambalpur',
#  'Kanyakumari',
#  'Vadodara',
#  'North Goa',
#  'Rayagada',
#  'S.P.S. Nellore',
#  'Salem',
#  'Kamrup Metropolitan',
#  'Karur',
#  'Thanjavur',
#  'Nayagarh',
#  'Jagatsinghpur',
#  'Surat',
#  'Prakasam',
#  'Balangir',
#  'Kendujhar',
#  'Krishnagiri',
#  'Kendrapara',
#  'Krishna',
#  'Angul',
#  'Jamui',
#  'Hyderabad',
#  'Other State',
#  'Vellore',
#  'Churachandpur',
#  'Thoubal',
#  'Kandhamal',
#  'Wayanad',
#  'Jaipur',
#  'Malkangiri',
#  'Gautam Buddha Nagar',
#  'Gajapati',
#  'Nuapada',
#  'Tirupathur',
#  'Mumbai',
#  'West Godavari',
#  'Jharsuguda',
#  'Pathanamthitta',
#  'Y.S.R. Kadapa',
#  'Bargarh',
#  'Pune',
#  'Panji',
#  'Pauri Garhwal',
#  'Kalahandi',
#  'Chittoor',
#  'Sivaganga',
#  'Pudukkottai',
#  'Dhenkanal',
#  'Idukki',
#  'Dispur',
#  'Anantapur',
#  'Erode',
#  'Bishnupur',
#  'Bhavnagar',
#  'East Godavari',
#  'Tiruchirappalli',
#  'Visakhapatnam',
#  'Hisar',
#  'Nabarangapur',
#  'Kolkata',
#  'Haridwar',
#  'Subarnapur',
#  'Dharmapuri',
#  'Nilgiris',
#  'Dadra and Nagar Haveli',
#  'Puducherry',
#  'Tiruppur',
#  'Koraput',
#  'Rajkot',
#  'Jorhat',
#  'Srinagar',
#  'KALABURAGI',
#  'Tinsukia',
#  'S.A.S. Nagar',
#  'Thiruvarur',
#  'Indore',
#  'Boudh',
#  'Aizawl',
#  'Kamrup',
#  'Shahid Bhagat Singh Nagar',
#  'Nagapattinam',
#  'Thane',
#  'GAYA',
#  'Ajmer',
#  'Dibrugarh',
#  'Kangpokpi',
#  'Kakching',
#  'DAKSHINA KANNADA',
#  'Gandhinagar',
#  'Jhunjhunu',
#  'Golaghat',
#  'Kangra',
#  'Pherzawl',
#  'Uttarkashi',
#  'East Khasi Hills',
#  'KOPPAL',
#  'Bandipora',
#  'Sonitpur',
#  'Nadia',
#  'Nagaon',
#  'Jabalpur',
#  'Lucknow',
#  'Anand',
#  'Railway Quarantine',
#  'HAVERI',
#  'Cachar',
#  'Raipur',
#  'Amritsar',
#  'Ghaziabad',
#  'Korba',
#  'Delhi',
#  'Jalandhar',
#  'Sivasagar',
#  'Chandel',
#  'Tamenglong',
#  'Patan',
#  'Jodhpur',
#  'Barpeta',
#  'Almora',
#  'Mandi',
#  'Biswanath',
#  'Ujjain',
#  'North West Delhi',
#  'Nashik',
#  'Ambala',
#  'South West Delhi',
#  'Ludhiana',
#  'Ranchi',
#  'Gurugram',
#  'RAICHUR',
#  'Panchmahal',
#  'North Delhi',
#  'Deogarh',
#  'HASSAN',
#  'Agra',
#  'Nagpur',
#  'North 24 Parganas',
#  'Jamnagar',
#  'Daman',
#  'Faridabad',
#  'Karimganj',
#  'Pithoragarh',
#  'Shillong',
#  'Leh',
#  'Bongaigaon',
#  'Hoshiarpur',
#  'Karimnagar',
#  'Gangtok',
#  'Ranga Reddy',
#  'Ukhrul',
#  'Patiala',
#  'Bhilwara',
#  'Udalguri',
#  'Chamba',
#  'Panipat',
#  'Lunglei',
#  'Purba Medinipur',
#  'Imphal',
#  'Kutch',
#  'Pilibhit',
#  'UTTARA KANNADA',
#  'Porbandar',
#  'MANDYA',
#  'Amroha',
#  'Baksa',
#  'Kokrajhar',
#  'Goalpara',
#  'TENKASI',
#  'Durg',
#  'CAPF Personnel',
#  'Evacuees',
#  'Solapur',
#  'Tehri Garhwal',
#  'Pathankot',
#  'Nalbari',
#  'Bhopal',
#  'Karbi Anglong',
#  'Bengaluru urban',
#  'Kota',
#  'Bhadradri Kothagudem',
#  'Rupnagar',
#  'UDUPI',
#  'BAGALKOTE',
#  'Satara',
#  'Sabarkantha',
#  'Sonipat',
#  'Chhota Udaipur',
#  'Jaunpur',
#  'Kalimpong',
#  'Mahe',
#  'East Delhi',
#  'Mehsana',
#  'Majuli',
#  'Moradabad',
#  'South Garo Hills',
#  'East Sikkim',
#  'Champawat',
#  'Una',
#  'Faridkot',
#  'Medchal Malkajgiri',
#  'Senapati',
#  'Papum Pare',
#  'Kapurthala',
#  'Morbi',
#  'Ahmednagar',
#  'Baghpat',
#  'Saiha',
#  'Gwalior',
#  'Moga',
#  'Howrah',
#  'West Delhi',
#  'Jammu',
#  'Barnala',
#  'Raigad',
#  'Yavatmal',
#  'Tengnoupal',
#  'Meerut',
#  'Dungarpur',
#  'Rajnandgaon',
#  'Chhindwara',
#  'Varanasi',
#  'North East Delhi',
#  'North and Middle Andaman',
#  'North Tripura',
#  'Darrang',
#  'Morigaon',
#  'South Delhi',
#  'Noney',
#  'West Garo Hills',
#  'Panchkula',
#  'Andaman',
#  'Charaideo']

# %%
b=[]
for i in a:
    df3=df[(df['Detected District']==i)]
    b.append(df3['Class Zone'][df3.index[-1]])
a=pd.DataFrame(a)
b=pd.DataFrame(b)

# %%
len(b)
# Out:
# 351

# %%
a=pd.concat([a,b],axis=1)

# %%
a.columns =['District', 'Zone']

# %%
a
# Out:
#              District         Zone
# 0     Bengaluru Urban     Red Zone
# 1             Chennai     Red Zone
# 2    Dakshina Kannada  Orange Zone
# 3          Chandigarh     Red Zone
# 4             Ballari  Orange Zone
# ..                ...          ...
# 346             Noney   Green Zone
# 347   West Garo Hills   Green Zone
# 348         Panchkula  Orange Zone
# 349           Andaman  Orange Zone
# 350         Charaideo   Green Zone
#
# [351 rows x 2 columns]

# %%
df_d3=pd.merge(df_d3,a)

# %%
df_d3['Zone'].value_counts()
# Out:
# Orange Zone    161
# Red Zone        67
# Green Zone      57
# Name: Zone, dtype: int64

# %%
df_d3
# Out:
#            Date           State           District  Confirmed  Recovered  \
# 0    2021-01-02  Andhra Pradesh          Anantapur      67374      66641
# 1    2021-01-02  Andhra Pradesh           Chittoor      86248      85087
# 2    2021-01-02  Andhra Pradesh      East Godavari     123755     122747
# 3    2021-01-02  Andhra Pradesh             Guntur      74830      73659
# 4    2021-01-02  Andhra Pradesh            Krishna      47871      46670
# ..          ...             ...                ...        ...        ...
# 280  2021-01-02     West Bengal          Kalimpong       2173       2102
# 281  2021-01-02     West Bengal            Kolkata     123816     118303
# 282  2021-01-02     West Bengal              Nadia      21782      20874
# 283  2021-01-02     West Bengal  North 24 Parganas     117180     112891
# 284  2021-01-02     West Bengal    Purba Medinipur      20162      19410
#
#      Deceased  Other    Tested         Zone
# 0         597      0  809025.0  Orange Zone
# 1         842      0  791735.0     Red Zone
# 2         636      0  967422.0  Orange Zone
# 3         665      0  852177.0     Red Zone
# 4         666      0  803134.0     Red Zone
# ..        ...    ...       ...          ...
# 280        24      0       NaN     Red Zone
# 281      2964      0       NaN     Red Zone
# 282       291      0       NaN  Orange Zone
# 283      2351      0       NaN  Orange Zone
# 284       273      0       NaN  Orange Zone
#
# [285 rows x 9 columns]

# %%
a=[]
for i in df['Detected District'].value_counts().index:
    a.append(i)

# %%
b=[]
for i in a:
    df3=df[(df['Detected District']==i)]
    x=df3['Age Bracket'].value_counts().index[0]
    b.append(x)
a=pd.DataFrame(a)
b=pd.DataFrame(b)

# %%
b.value_counts()
# Out:
# Young             233
# Senior Citizen     83
# Children           35
# dtype: int64

# %%
a=pd.DataFrame(a)
b=pd.DataFrame(b)
a=pd.concat([a,b],axis=1)

# %%
a.columns =['District', 'Age Bracket']

# %%
df_d3=pd.merge(df_d3,a)

# %%
df_d3
# Out:
#            Date           State           District  Confirmed  Recovered  \
# 0    2021-01-02  Andhra Pradesh          Anantapur      67374      66641
# 1    2021-01-02  Andhra Pradesh           Chittoor      86248      85087
# 2    2021-01-02  Andhra Pradesh      East Godavari     123755     122747
# 3    2021-01-02  Andhra Pradesh             Guntur      74830      73659
# 4    2021-01-02  Andhra Pradesh            Krishna      47871      46670
# ..          ...             ...                ...        ...        ...
# 280  2021-01-02     West Bengal          Kalimpong       2173       2102
# 281  2021-01-02     West Bengal            Kolkata     123816     118303
# 282  2021-01-02     West Bengal              Nadia      21782      20874
# 283  2021-01-02     West Bengal  North 24 Parganas     117180     112891
# 284  2021-01-02     West Bengal    Purba Medinipur      20162      19410
#
#      Deceased  Other    Tested         Zone Age Bracket
# 0         597      0  809025.0  Orange Zone       Young
# 1         842      0  791735.0     Red Zone       Young
# 2         636      0  967422.0  Orange Zone    Children
# 3         665      0  852177.0     Red Zone       Young
# 4         666      0  803134.0     Red Zone       Young
# ..        ...    ...       ...          ...         ...
# 280        24      0       NaN     Red Zone       Young
# 281      2964      0       NaN     Red Zone       Young
# 282       291      0       NaN  Orange Zone    Children
# 283      2351      0       NaN  Orange Zone    Children
# 284       273      0       NaN  Orange Zone       Young
#
# [285 rows x 10 columns]

# %%
a=[]
for i in df['Detected District'].value_counts().index:
    a.append(i)

# %%
b=[]
for i in a:
    df3=df[(df['Detected District']==i)]
    x=df3['Type of transmission'].value_counts().index[0]
    b.append(x)

# %%
a=pd.DataFrame(a)
b=pd.DataFrame(b)
a=pd.concat([a,b],axis=1)

# %%
a.columns =['District', 'Transmission Type']

# %%
df_d3=pd.merge(df_d3,a)

# %%
df_d3.head(5)
# Out:
#          Date           State       District  Confirmed  Recovered  Deceased  \
# 0  2021-01-02  Andhra Pradesh      Anantapur      67374      66641       597
# 1  2021-01-02  Andhra Pradesh       Chittoor      86248      85087       842
# 2  2021-01-02  Andhra Pradesh  East Godavari     123755     122747       636
# 3  2021-01-02  Andhra Pradesh         Guntur      74830      73659       665
# 4  2021-01-02  Andhra Pradesh        Krishna      47871      46670       666
#
#    Other    Tested         Zone Age Bracket Transmission Type
# 0      0  809025.0  Orange Zone       Young             Local
# 1      0  791735.0     Red Zone       Young             Local
# 2      0  967422.0  Orange Zone    Children             Local
# 3      0  852177.0     Red Zone       Young             Local
# 4      0  803134.0     Red Zone       Young             Local

# %%
a=[]
for i in df['Detected District'].value_counts().index:
    a.append(i)

# %%
b=[]
for i in a:
    df3=df[(df['Detected District']==i)]
    b.append(df3['Population Density'][df3.index[-1]])
a=pd.DataFrame(a)
b=pd.DataFrame(b)

# %%
a=pd.concat([a,b],axis=1)

# %%
a.columns =['District', 'Population Density']

# %%
df_d3=pd.merge(df_d3,a)

# %%
df_d3.shape
# Out:
# (285, 12)

# %%
for i in df_d3['Age Bracket']:
    if i=='Senior Citizen':
        df_d3['Age Bracket']=df_d3['Age Bracket'].replace(i,0)
    if i=='Young':
        df_d3['Age Bracket']=df_d3['Age Bracket'].replace(i,1)
    else:
        df_d3['Age Bracket']=df_d3['Age Bracket'].replace(i,2)

# %%
for i in df_d3['Zone']:
    if i=='Red Zone':
        df_d3['Zone']=df_d3['Zone'].replace(i,0)
    if i=='Orange Zone':
        df_d3['Zone']=df_d3['Zone'].replace(i,1)
    if i=='Green Zone':
        df_d3['Zone']=df_d3['Zone'].replace(i,2)

# %%
for i in df_d3['Transmission Type']:
    if i=='Imported':
        df_d3['Transmission Type']=df_d3['Transmission Type'].replace(i,0)
    if i=='Local':
        df_d3['Transmission Type']=df_d3['Transmission Type'].replace(i,1)

# %%
df_d3=df_d3.drop(['Other','Tested'],axis=1)

# %%
df_d3.to_csv(r'C:\Users\ASUS\Desktop\file3 .csv', index=False)

# %%
df_d3.head(5)
# Out:
#          Date           State       District  Confirmed  Recovered  Deceased  \
# 0  2021-01-02  Andhra Pradesh      Anantapur      67374      66641       597
# 1  2021-01-02  Andhra Pradesh       Chittoor      86248      85087       842
# 2  2021-01-02  Andhra Pradesh  East Godavari     123755     122747       636
# 3  2021-01-02  Andhra Pradesh         Guntur      74830      73659       665
# 4  2021-01-02  Andhra Pradesh        Krishna      47871      46670       666
#
#    Zone  Age Bracket  Transmission Type  Population Density
# 0     1            2                  1                 191
# 1     0            2                  1                 191
# 2     1            2                  1                 191
# 3     0            2                  1                 191
# 4     0            2                  1                 191
